# %%
import numpy as np
import matplotlib.pyplot as plt
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
a = np.random.randn(8,3*3)
a
# Out:
# array([[-1.09549449e+00, -6.15315574e-01, -7.46262136e-01,
#         -4.47154477e-01, -8.17519395e-01,  5.15300052e-02,
#          5.28073622e-02,  3.38628377e-01,  1.06009246e+00],
#        [-1.87805322e+00,  2.93787850e-01,  4.10147079e-01,
#         -3.99690116e-01, -2.69217135e+00, -1.14747028e+00,
#         -4.08190980e-01, -1.60150003e-02, -1.73438196e+00],
#        [-2.95540715e-01,  8.60674975e-01,  1.62578005e+00,
#          3.39913342e-01, -8.37286197e-01, -4.82304950e-04,
#          6.60836683e-01, -6.36582108e-01, -6.20592045e-01],
#        [-9.24983627e-01,  1.44615064e+00, -2.39306790e-01,
#          1.81462402e+00,  1.00292578e+00,  1.35554460e+00,
#          1.92227928e-02, -1.25873888e+00,  1.30133116e-01],
#        [ 1.06264768e+00,  1.75535031e+00, -1.76100036e+00,
#          2.00435808e+00, -3.06731764e-01, -8.61574366e-01,
#         -1.38694559e+00,  8.43560409e-01, -3.32888594e-01],
#        [ 3.44424830e-01,  2.15271683e+00, -6.60335989e-02,
#         -6.44674138e-01, -2.84232828e+00, -1.22478015e-01,
#          6.49034340e-01, -3.93696958e-01, -3.05162695e-01],
#        [ 2.28448364e-01, -2.19122382e+00, -6.06455281e-01,
#         -6.57548440e-01,  1.88608791e+00,  1.72580465e-01,
#         -1.96313346e+00, -7.57887875e-01,  5.55168866e-01],
#        [-6.27766002e-01,  4.51173521e-01,  1.67132165e+00,
#         -9.48132867e-01, -5.67341084e-02,  1.85199057e-01,
#         -3.20470194e-01, -1.05055242e-01, -4.31359553e-01]])

# %%
def plot(func,title, x = np.linspace(-10,10,100)):
    fig,ax = plt.subplots()
    ax.plot(x,func(x))
    ax.grid()
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.spines['bottom'].set_position(('data',0)) #установка положения оси 0x
    ax.spines['left'].set_position(('data',0)) #установка положения оси 0y
    plt.title(title)
    plt.show()

# %% [markdown]
# ## Activation function

# %% [markdown]
# 1. ReLU
#
# $$ f(z)=max(0, z) $$
# $$f'(z)\begin{cases}
#     0, &z <= 0\\
#     1, &z > 0
# \end{cases}
# $$

# %%
def ReLU(z:np.ndarray) -> np.ndarray:
    return np.maximum(0,z)
def dReLU(z:np.ndarray) -> np.ndarray:
    return (z > 0).astype("int8")

# %%
ReLU(a)
# Out:
# array([[0.        , 0.        , 0.        , 0.        , 0.        ,
#         0.05153001, 0.05280736, 0.33862838, 1.06009246],
#        [0.        , 0.29378785, 0.41014708, 0.        , 0.        ,
#         0.        , 0.        , 0.        , 0.        ],
#        [0.        , 0.86067497, 1.62578005, 0.33991334, 0.        ,
#         0.        , 0.66083668, 0.        , 0.        ],
#        [0.        , 1.44615064, 0.        , 1.81462402, 1.00292578,
#         1.3555446 , 0.01922279, 0.        , 0.13013312],
#        [1.06264768, 1.75535031, 0.        , 2.00435808, 0.        ,
#         0.        , 0.        , 0.84356041, 0.        ],
#        [0.34442483, 2.15271683, 0.        , 0.        , 0.        ,
#         0.        , 0.64903434, 0.        , 0.        ],
#        [0.22844836, 0.        , 0.        , 0.        , 1.88608791,
#         0.17258046, 0.        , 0.        , 0.55516887],
#        [0.        , 0.45117352, 1.67132165, 0.        , 0.        ,
#         0.18519906, 0.        , 0.        , 0.        ]])

# %%
plot(ReLU, "ReLU")

# %%
plot(dReLU, "Derivetive of ReLU")

# %% [markdown]
# 2. ELU
# $$f(z) = \begin{cases}
# x, & x\geq 0\\
# \alpha(e^z-1), & x<0
# \end{cases}$$
#
# $$f'(z) = \begin{cases}
# 1, & x\geq 0\\
# \alpha e^z, & x<0
# \end{cases}$$

# %%
def ELU(z:np.ndarray, alpha = 1.0) -> np.ndarray:
    return (z >= 0) * z + (z < 0) * alpha * (np.exp(z) - 1)
def dELU(z:np.ndarray, alpha = 1.0) -> np.ndarray:
    return (z >= 0) * 1 + (z < 0) * alpha * np.exp(z)

# %%
ELU(a)
# Out:
# array([[-6.65625779e-01, -4.59529690e-01, -5.25864502e-01,
#         -3.60554879e-01, -5.58474453e-01,  5.15300052e-02,
#          5.28073622e-02,  3.38628377e-01,  1.06009246e+00],
#        [-8.47112545e-01,  2.93787850e-01,  4.10147079e-01,
#         -3.29472201e-01, -9.32266294e-01, -6.82561213e-01,
#         -3.35148106e-01, -1.58874420e-02, -8.23490744e-01],
#        [-2.55870883e-01,  8.60674975e-01,  1.62578005e+00,
#          3.39913342e-01, -5.67116308e-01, -4.82188659e-04,
#          6.60836683e-01, -4.70902264e-01, -4.62373956e-01],
#        [-6.03462088e-01,  1.44615064e+00, -2.12826652e-01,
#          1.81462402e+00,  1.00292578e+00,  1.35554460e+00,
#          1.92227928e-02, -7.15988025e-01,  1.30133116e-01],
#        [ 1.06264768e+00,  1.75535031e+00, -8.28127157e-01,
#          2.00435808e+00, -2.64152045e-01, -5.77503606e-01,
#         -7.50162755e-01,  8.43560409e-01, -2.83149949e-01],
#        [ 3.44424830e-01,  2.15271683e+00, -6.39005882e-02,
#         -4.75166463e-01, -9.41710207e-01, -1.15274645e-01,
#          6.49034340e-01, -3.25441555e-01, -2.62996542e-01],
#        [ 2.28448364e-01, -8.88220134e-01, -4.54719687e-01,
#         -4.81880019e-01,  1.88608791e+00,  1.72580465e-01,
#         -8.59582262e-01, -5.31344759e-01,  5.55168866e-01],
#        [-4.66217060e-01,  4.51173521e-01,  1.67132165e+00,
#         -6.12536205e-01, -5.51547377e-02,  1.85199057e-01,
#         -2.74192314e-01, -9.97252118e-02, -3.50374706e-01]])

# %%
plot(ELU, "ELU")

# %%
plot(dELU, "Derivetive of ELU")

# %% [markdown]
# ![image.png](attachment:321714c1-0c49-42da-b2a0-f36a01feaed5.png)

# %% [markdown]
# 3.SiLU
#
# $$
# f(z) = z(\frac{1}{1+e^{-z}})
# $$
# $$
# f'(z) = \dfrac{{e}^{-z}(z+1)+1}{\left({{e}^{-z}+1}\right)^{2}}
# $$

# %%
def SiLU(z:np.ndarray) -> np.ndarray:
    return z*(1/(1+np.exp(-z)))
def dSiLU(z:np.ndarray) -> np.ndarray:
    return (np.exp(-z)*(z+1)+1)/(np.exp(-z)+1)**2

# %%
SiLU(a)
# Out:
# array([[-2.74514534e-01, -2.15881992e-01, -2.40024998e-01,
#         -1.74407026e-01, -2.50398406e-01,  2.64286911e-02,
#          2.71006735e-02,  1.97710650e-01,  7.87339379e-01],
#        [-2.49053605e-01,  1.68317877e-01,  2.46548902e-01,
#         -1.60430335e-01, -1.70782978e-01, -2.76484628e-01,
#         -1.63009422e-01, -7.94338146e-03, -2.60205747e-01],
#        [-1.26091841e-01,  6.04883798e-01,  1.35848673e+00,
#          1.98566998e-01, -2.52949728e-01, -2.41094320e-04,
#          4.35787636e-01, -2.20269865e-01, -2.16988030e-01],
#        [-2.62643121e-01,  1.17052201e+00, -1.05404396e-01,
#          1.56043113e+00,  7.33774034e-01,  1.07770489e+00,
#          9.70377252e-03, -2.78421791e-01,  6.92942502e-02],
#        [ 7.89755713e-01,  1.49665794e+00, -2.58277287e-01,
#          1.76634836e+00, -1.30027483e-01, -2.55896651e-01,
#         -2.77244631e-01,  5.89829711e-01, -1.38993621e-01],
#        [ 2.01579786e-01,  1.92866719e+00, -3.19270864e-02,
#         -2.21890849e-01, -1.56553269e-01, -5.74934726e-02,
#          4.26281095e-01, -1.58592021e-01, -1.29479282e-01],
#        [ 1.27214898e-01, -2.20308636e-01, -2.13998795e-01,
#         -2.24415059e-01,  1.63770679e+00,  9.37178104e-02,
#         -2.41717355e-01, -2.41845816e-01,  3.52717641e-01],
#        [-2.18473405e-01,  2.75630121e-01,  1.40683826e+00,
#         -2.64776032e-01, -2.75625802e-02,  1.01149777e-01,
#         -1.34777317e-01, -4.97710049e-02, -1.69870138e-01]])

# %%
plot(SiLU, "SiLU")

# %%
plot(dSiLU, "Derivetive of SiLU")

# %% [markdown]
# ![image.png](attachment:5d4390ad-32e8-4dec-b699-30521289c268.png)

# %% [markdown]
# 4. Softplus
#
# $$
# f(z) = ln(1+e^x)
# $$
# $$
# f'(z) = \frac{e^x}{1+e^x}
# $$

# %%
def Softplus (z:np.ndarray) -> np.ndarray:
    return np.log(1+np.exp(z))
def dSoftplus(z:np.ndarray) -> np.ndarray:
    return np.exp(z)/(1+np.exp(z))

# %%
Softplus(a)
# Out:
# array([[0.28846243, 0.43208777, 0.38807172, 0.49435784, 0.36570196,
#         0.71924406, 0.7198994 , 0.87672705, 1.35754449],
#        [0.14226963, 0.85079144, 0.91910254, 0.51313962, 0.06553837,
#         0.27568954, 0.50973617, 0.68517174, 0.1625518 ],
#        [0.55625536, 1.21335554, 1.8053964 , 0.87747749, 0.35968898,
#         0.69290606, 1.07718837, 0.42467785, 0.4302397 ],
#        [0.33399625, 1.65760613, 0.58063524, 1.96554017, 1.31540145,
#         1.58491421, 0.70280477, 0.24998953, 0.76032907],
#        [1.35944289, 1.91478416, 0.15860319, 2.13076759, 0.55149603,
#         0.35241335, 0.22301334, 1.20135806, 0.54049125],
#        [0.88011543, 2.26261833, 0.66067534, 0.42188525, 0.0566542 ,
#         0.63378211, 1.06942099, 0.51554952, 0.55216148],
#        [0.81388081, 0.10596221, 0.43520533, 0.41747271, 2.02729574,
#         0.7831558 , 0.13139463, 0.38434718, 1.00877334],
#        [0.42773719, 0.94396571, 1.84359155, 0.32747747, 0.66518242,
#         0.79002793, 0.54569516, 0.6419985 , 0.50054817]])

# %%
plot(Softplus, "Softplus")

# %%
plot(dSoftplus, "Derivetive of Softplus")

# %% [markdown]
# ![image.png](attachment:c8525f32-563b-4f2c-9c00-dff0795486fe.png)

# %%
def Mish (z:np.ndarray) -> np.ndarray:
    return z*np.tanh(np.log(1+np.exp(z)))

def mish_derivative(x):
    omega = np.exp(3*x) + 4*np.exp(2*x) + (6+4*x)*np.exp(x) + 4*(1 + x)
    delta = 1 + pow((np.exp(x) + 1), 2)
    derivative = np.exp(x) * omega / pow(delta, 2)
    return derivative

# %%
plot(Mish, "Mish")

# %%
plot(mish_derivative, "Derivetive of Mish")

# %% [markdown]
# ## Loss function

# %%
a = np.random.randn(8,3*3)
b = np.random.randn(8,3*3)

# %% [markdown]
# ![image.png](attachment:e2bfddbd-2ead-4941-afad-c6c301827e57.png)

# %%
def MSE(y_pred,y_true):
    return ((y_pred-y_true)**2).mean()

# %%
MSE(a,b)
# Out:
# 2.0741169754575415
